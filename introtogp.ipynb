# %%
import geopandas as gpd
import matplotlib.pyplot as plt

land = gpd.read_file("california/tl_2024_06_place.shp")

# %%
land.head(3)
# Out:
#   STATEFP PLACEFP   PLACENS    GEOID           GEOIDFQ       NAME  \
# 0      06   14218  02409488  0614218  1600000US0614218     Clovis
# 1      06   27000  02410546  0627000  1600000US0627000     Fresno
# 2      06   13945  02409479  0613945  1600000US0613945  Clearlake
#
#          NAMELSAD LSAD CLASSFP PCICBSA  MTFCC FUNCSTAT      ALAND   AWATER  \
# 0     Clovis city   25      C1       N  G4110        A   68002602   309836
# 1     Fresno city   25      C1       Y  G4110        A  300202535  3114247
# 2  Clearlake city   25      C1       Y  G4110        A   26235110  1167608
#
#       INTPTLAT      INTPTLON  \
# 0  +36.8278093  -119.6818434
# 1  +36.7826843  -119.7933595
# 2  +38.9600452  -122.6332316
#
#                                             geometry
# 0  MULTIPOLYGON (((-119.61479 36.79625, -119.6126...
# 1  MULTIPOLYGON (((-119.69999 36.73098, -119.6999...
# 2  POLYGON ((-122.69949 38.97838, -122.69932 38.9...

# %%
land.columns
# Out:
# Index(['STATEFP', 'PLACEFP', 'PLACENS', 'GEOID', 'GEOIDFQ', 'NAME', 'NAMELSAD',
#        'LSAD', 'CLASSFP', 'PCICBSA', 'MTFCC', 'FUNCSTAT', 'ALAND', 'AWATER',
#        'INTPTLAT', 'INTPTLON', 'geometry'],
#       dtype='object')

# %%
land.plot(figsize=[3,3])
# Out:
# <Axes: >
